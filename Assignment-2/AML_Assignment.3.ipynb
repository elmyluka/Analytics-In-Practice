# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

import numpy as np

max_features = 10000  # consider only top 10,000 words
maxlen = 150  # cutoff reviews after 150 words
batch_size = 32
embedding_dim = 100
lstm_units = 64
epochs = 30

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=max_features)
train_data = train_data[:100]
train_labels = train_labels[:100]

train_data = sequence.pad_sequences(train_data, maxlen=maxlen)
test_data = sequence.pad_sequences(test_data, maxlen=maxlen)

model = Sequential()
model.add(Embedding(max_features, embedding_dim, input_length=maxlen))
model.add(LSTM(lstm_units))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_data, train_labels, batch_size=batch_size, epochs=epochs, 
                    validation_split=0.2, validation_data=(test_data[:10000], test_labels[:10000]))

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

scores = model.evaluate(test_data[:10000], test_labels[:10000], verbose=0)
print(f'Test accuracy: {scores[1]*100:.2f}%')
# Out:
# Epoch 1/30
# 4/4 [==============================] - 5s 724ms/step - loss: 0.6919 - accuracy: 0.5700 - val_loss: 0.6928 - val_accuracy: 0.5099
# Epoch 2/30
# 4/4 [==============================] - 2s 544ms/step - loss: 0.6831 - accuracy: 0.7800 - val_loss: 0.6925 - val_accuracy: 0.5262
# Epoch 3/30
# 4/4 [==============================] - 2s 540ms/step - loss: 0.6744 - accuracy: 0.9200 - val_loss: 0.6919 - val_accuracy: 0.5340
# Epoch 4/30
# 4/4 [==============================] - 2s 551ms/step - loss: 0.6590 - accuracy: 0.9700 - val_loss: 0.6913 - val_accuracy: 0.5261
# Epoch 5/30
# 4/4 [==============================] - 2s 548ms/step - loss: 0.6311 - accuracy: 0.9200 - val_loss: 0.6925 - val_accuracy: 0.5055
# Epoch 6/30
# 4/4 [==============================] - 2s 505ms/step - loss: 0.5686 - accuracy: 0.8000 - val_loss: 1.0839 - val_accuracy: 0.5027
# Epoch 7/30
# 4/4 [==============================] - 2s 535ms/step - loss: 0.6092 - accuracy: 0.6700 - val_loss: 0.6933 - val_accuracy: 0.5131
# Epoch 8/30
# 4/4 [==============================] - 2s 440ms/step - loss: 0.4744 - accuracy: 0.9700 - val_loss: 0.6843 - val_accuracy: 0.5508
# Epoch 9/30
# 4/4 [==============================] - 2s 480ms/step - loss: 0.4538 - accuracy: 1.0000 - val_loss: 0.6812 - val_accuracy: 0.5637
# Epoch 10/30
# 4/4 [==============================] - 2s 472ms/step - loss: 0.4121 - accuracy: 1.0000 - val_loss: 0.6793 - val_accuracy: 0.5664
# Epoch 11/30
# 4/4 [==============================] - 2s 533ms/step - loss: 0.3566 - accuracy: 1.0000 - val_loss: 0.6792 - val_accuracy: 0.5654
# Epoch 12/30
# 4/4 [==============================] - 2s 558ms/step - loss: 0.2921 - accuracy: 1.0000 - val_loss: 0.6840 - val_accuracy: 0.5642
# Epoch 13/30
# 4/4 [==============================] - 2s 552ms/step - loss: 0.2278 - accuracy: 1.0000 - val_loss: 0.6991 - val_accuracy: 0.5633
# Epoch 14/30
# 4/4 [==============================] - 2s 563ms/step - loss: 0.1716 - accuracy: 1.0000 - val_loss: 0.7313 - val_accuracy: 0.5625
# Epoch 15/30
# 4/4 [==============================] - 1s 470ms/step - loss: 0.1307 - accuracy: 1.0000 - val_loss: 0.7783 - val_accuracy: 0.5654
# Epoch 16/30
# 4/4 [==============================] - 2s 535ms/step - loss: 0.1024 - accuracy: 1.0000 - val_loss: 0.8167 - val_accuracy: 0.5661
# Epoch 17/30
# 4/4 [==============================] - 2s 476ms/step - loss: 0.0777 - accuracy: 1.0000 - val_loss: 0.8396 - val_accuracy: 0.5656
# Epoch 18/30
# 4/4 [==============================] - 2s 473ms/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 0.8453 - val_accuracy: 0.5603
# Epoch 19/30
# 4/4 [==============================] - 2s 441ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.8643 - val_accuracy: 0.5595
# Epoch 20/30
# 4/4 [==============================] - 1s 417ms/step - loss: 0.0384 - accuracy: 1.0000 - val_loss: 0.8909 - val_accuracy: 0.5556
# Epoch 21/30
# 4/4 [==============================] - 2s 544ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.9205 - val_accuracy: 0.5530
# Epoch 22/30
# 4/4 [==============================] - 2s 542ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.9496 - val_accuracy: 0.5508
# Epoch 23/30
# 4/4 [==============================] - 2s 550ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.9780 - val_accuracy: 0.5500
# Epoch 24/30
# 4/4 [==============================] - 2s 476ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 1.0049 - val_accuracy: 0.5490
# Epoch 25/30
# 4/4 [==============================] - 1s 411ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 1.0310 - val_accuracy: 0.5477
# Epoch 26/30
# 4/4 [==============================] - 2s 586ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 1.0563 - val_accuracy: 0.5474
# Epoch 27/30
# 4/4 [==============================] - 1s 346ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 1.0820 - val_accuracy: 0.5458
# Epoch 28/30
# 4/4 [==============================] - 2s 472ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.1091 - val_accuracy: 0.5437
# Epoch 29/30
# 4/4 [==============================] - 1s 475ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.1352 - val_accuracy: 0.5403
# Epoch 30/30
# 4/4 [==============================] - 1s 407ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.1620 - val_accuracy: 0.5395
# Test accuracy: 53.95%

# %%
# Import required libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Dropout
import urllib.request
import zipfile

# URL for the GloVe embeddings zip file
url = 'https://nlp.stanford.edu/data/glove.6B.zip'

# Download the file from the URL
urllib.request.urlretrieve(url, 'glove.6B.zip')

# Extract the contents of the zip file to a directory called "glove.6B"
with zipfile.ZipFile('glove.6B.zip', 'r') as zip_ref:
    zip_ref.extractall('./glove.6B')

# Set parameters
max_features = 10000  # Consider only the top 10,000 words
max_len = 150         # Cutoff reviews after 150 words
batch_size = 32       # Batch size
epochs = 30           # Number of epochs

# Load the data and restrict training samples to 100
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
x_train = x_train[:100]
y_train = y_train[:100]

# Pad sequences to a fixed length and truncate longer sequences
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

# Load pre-trained word embeddings
# !wget -nc https://nlp.stanford.edu/data/glove.6B.zip
# !unzip -n glove.6B.zip
glove_dir = './glove.6B/'
embeddings_index = {}
with open(glove_dir + 'glove.6B.100d.txt', 'r') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# Create an embedding matrix
embedding_dim = 100
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in imdb.get_word_index().items():
    if i < max_features:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector

# Build the model
model = Sequential()
model.add(Embedding(max_features, embedding_dim, input_length=max_len))
model.add(LSTM(32, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.layers[0].set_weights([embedding_matrix])
model.layers[0].trainable = False
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])

# Fit the model and validate on 10,000 samples
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test[:10000], y_test[:10000]))

# Evaluate the model on the test data
results = model.evaluate(x_test, y_test)
print('Test loss:', results[0])
print('Test accuracy:', results[1])

import matplotlib.pyplot as plt

# Plot training and validation accuracy
acc = history.history['acc']
val_acc = history.history['val_acc']
epochs_range = range(1, epochs+1)
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# Plot training and validation loss
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# Print the training sample size
print('Training sample size:', len(x_train))
# Out:
# File ‘glove.6B.zip’ already there; not retrieving.
#
# Archive:  glove.6B.zip
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 150, 100)          1000000
#
#  lstm_2 (LSTM)               (None, 32)                17024
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,017,057
# Trainable params: 1,017,057
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 4/4 [==============================] - 16s 4s/step - loss: 0.7277 - acc: 0.4300 - val_loss: 0.7463 - val_acc: 0.5022
# Epoch 2/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6999 - acc: 0.5700 - val_loss: 0.7030 - val_acc: 0.5000
# Epoch 3/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6875 - acc: 0.5300 - val_loss: 0.6976 - val_acc: 0.4994
# Epoch 4/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6781 - acc: 0.5600 - val_loss: 0.6972 - val_acc: 0.4930
# Epoch 5/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6794 - acc: 0.5900 - val_loss: 0.7052 - val_acc: 0.5018
# Epoch 6/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6595 - acc: 0.6200 - val_loss: 0.7053 - val_acc: 0.5030
# Epoch 7/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6485 - acc: 0.6100 - val_loss: 0.7106 - val_acc: 0.5018
# Epoch 8/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6503 - acc: 0.6000 - val_loss: 0.7083 - val_acc: 0.5030
# Epoch 9/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6432 - acc: 0.6300 - val_loss: 0.7131 - val_acc: 0.5024
# Epoch 10/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6346 - acc: 0.6300 - val_loss: 0.7079 - val_acc: 0.5023
# Epoch 11/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6396 - acc: 0.6800 - val_loss: 0.7010 - val_acc: 0.5040
# Epoch 12/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6209 - acc: 0.8000 - val_loss: 0.7003 - val_acc: 0.5036
# Epoch 13/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6091 - acc: 0.7100 - val_loss: 0.6991 - val_acc: 0.5022
# Epoch 14/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6238 - acc: 0.7800 - val_loss: 0.7239 - val_acc: 0.5018
# Epoch 15/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5835 - acc: 0.7000 - val_loss: 0.7059 - val_acc: 0.5064
# Epoch 16/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5890 - acc: 0.7000 - val_loss: 0.7081 - val_acc: 0.5104
# Epoch 17/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.6190 - acc: 0.7500 - val_loss: 0.7153 - val_acc: 0.5106
# Epoch 18/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5623 - acc: 0.8300 - val_loss: 0.7098 - val_acc: 0.5115
# Epoch 19/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5732 - acc: 0.7700 - val_loss: 0.7125 - val_acc: 0.5118
# Epoch 20/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5557 - acc: 0.7400 - val_loss: 0.7329 - val_acc: 0.5103
# Epoch 21/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5690 - acc: 0.7400 - val_loss: 0.7739 - val_acc: 0.5050
# Epoch 22/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5501 - acc: 0.7400 - val_loss: 0.7226 - val_acc: 0.5017
# Epoch 23/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5533 - acc: 0.7800 - val_loss: 0.7130 - val_acc: 0.5106
# Epoch 24/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5417 - acc: 0.7900 - val_loss: 0.7298 - val_acc: 0.5129
# Epoch 25/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5203 - acc: 0.8200 - val_loss: 0.7146 - val_acc: 0.5129
# Epoch 26/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5096 - acc: 0.8500 - val_loss: 0.8983 - val_acc: 0.5033
# Epoch 27/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.5345 - acc: 0.7400 - val_loss: 0.8421 - val_acc: 0.5049
# Epoch 28/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.4994 - acc: 0.7600 - val_loss: 0.8303 - val_acc: 0.5068
# Epoch 29/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.4951 - acc: 0.7700 - val_loss: 0.7405 - val_acc: 0.5041
# Epoch 30/30
# 4/4 [==============================] - 13s 4s/step - loss: 0.4894 - acc: 0.8200 - val_loss: 0.7644 - val_acc: 0.5155
# 782/782 [==============================] - 30s 39ms/step - loss: 0.7679 - acc: 0.5113
# Test loss: 0.7678860425949097
# Test accuracy: 0.5112800002098083
# Training sample size: 100

# %%
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.callbacks import EarlyStopping

train_sizes = [1000, 2500, 5000, 7500, 10000,15000,20000]
train_accs = []
val_accs = []
train_losses = []
val_losses = []
test_accs = []

early_stopping = EarlyStopping(monitor='val_loss', patience=3)

for size in train_sizes:
    print(f'Training with {size} samples...')
    train_data_subset = train_data[:size]
    train_labels_subset = train_labels[:size]

    history = model.fit(train_data_subset, train_labels_subset, batch_size=batch_size, epochs=epochs, 
                        validation_split=0.2, 
                        validation_data=(test_data[:10000], test_labels[:10000]),
                        callbacks=[early_stopping])

    train_accs.append(history.history['acc'][-1])  # final training accuracy
    val_accs.append(history.history['val_acc'][-1])  # final validation accuracy
    train_losses.append(history.history['loss'][-1])  # final training loss
    val_losses.append(history.history['val_loss'][-1])  # final validation loss

  
    scores = model.evaluate(test_data[:10000], test_labels[:10000], verbose=0)
    test_accs.append(scores[1])

    print(f'Test accuracy with {size} training samples: {scores[1]*100:.2f}%')

# plot training and validation accuracies
plt.plot(train_sizes, train_accs, label='Training Accuracy')
plt.plot(train_sizes, val_accs, label='Validation Accuracy')
plt.xlabel('Training Sample Size')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# plot training and validation losses
plt.plot(train_sizes, train_losses, label='Training Loss')
plt.plot(train_sizes, val_losses, label='Validation Loss')
plt.xlabel('Training Sample Size')
plt.ylabel('Loss')
plt.legend()
plt.show()

# plot test accuracies for each training sample
plt.plot(train_sizes, test_accs)
plt.xlabel('Training Sample Size')
plt.ylabel('Test Accuracy')
plt.show()

# create table for test accuracies
results_df = pd.DataFrame({'Training Sample Size': train_sizes, 'Test Accuracy': test_accs})
print(results_df.to_markdown(index=False))
# Out:
# Training with 1000 samples...
# Epoch 1/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.1955 - val_acc: 0.5023
# Epoch 2/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.1994 - val_acc: 0.5025
# Epoch 3/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.2024 - val_acc: 0.5051
# Epoch 4/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.0011 - acc: 1.0000 - val_loss: 1.2176 - val_acc: 0.5047
# Test accuracy with 1000 training samples: 50.47%
# Training with 2500 samples...
# Epoch 1/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.0010 - acc: 1.0000 - val_loss: 1.2345 - val_acc: 0.5024
# Epoch 2/30
# 4/4 [==============================] - 4s 1s/step - loss: 9.3383e-04 - acc: 1.0000 - val_loss: 1.2376 - val_acc: 0.5063
# Epoch 3/30
# 4/4 [==============================] - 5s 1s/step - loss: 8.6016e-04 - acc: 1.0000 - val_loss: 1.2451 - val_acc: 0.5037
# Epoch 4/30
# 4/4 [==============================] - 4s 1s/step - loss: 8.0191e-04 - acc: 1.0000 - val_loss: 1.2756 - val_acc: 0.5038
# Test accuracy with 2500 training samples: 50.38%
# Training with 5000 samples...
# Epoch 1/30
# 4/4 [==============================] - 5s 1s/step - loss: 7.4568e-04 - acc: 1.0000 - val_loss: 1.2680 - val_acc: 0.5059
# Epoch 2/30
# 4/4 [==============================] - 4s 1s/step - loss: 6.4741e-04 - acc: 1.0000 - val_loss: 1.2855 - val_acc: 0.4998
# Epoch 3/30
# 4/4 [==============================] - 4s 1s/step - loss: 6.0733e-04 - acc: 1.0000 - val_loss: 1.3083 - val_acc: 0.5008
# Epoch 4/30
# 4/4 [==============================] - 4s 1s/step - loss: 5.3912e-04 - acc: 1.0000 - val_loss: 1.3248 - val_acc: 0.5062
# Test accuracy with 5000 training samples: 50.62%
# Training with 7500 samples...
# Epoch 1/30
# 4/4 [==============================] - 5s 1s/step - loss: 4.9110e-04 - acc: 1.0000 - val_loss: 1.3699 - val_acc: 0.4948
# Epoch 2/30
# 4/4 [==============================] - 4s 1s/step - loss: 4.6975e-04 - acc: 1.0000 - val_loss: 1.3447 - val_acc: 0.5048
# Epoch 3/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.0604 - acc: 0.9800 - val_loss: 1.4902 - val_acc: 0.5046
# Epoch 4/30
# 4/4 [==============================] - 5s 2s/step - loss: 0.0419 - acc: 0.9800 - val_loss: 1.3367 - val_acc: 0.5026
# Epoch 5/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.0044 - acc: 1.0000 - val_loss: 1.3693 - val_acc: 0.5045
# Epoch 6/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.3715 - val_acc: 0.5049
# Epoch 7/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.0011 - acc: 1.0000 - val_loss: 1.3865 - val_acc: 0.5060
# Test accuracy with 7500 training samples: 50.60%
# Training with 10000 samples...
# Epoch 1/30
# 4/4 [==============================] - 5s 1s/step - loss: 9.7537e-04 - acc: 1.0000 - val_loss: 1.3713 - val_acc: 0.5061
# Epoch 2/30
# 4/4 [==============================] - 4s 1s/step - loss: 8.7230e-04 - acc: 1.0000 - val_loss: 1.3936 - val_acc: 0.5056
# Epoch 3/30
# 4/4 [==============================] - 4s 1s/step - loss: 7.8530e-04 - acc: 1.0000 - val_loss: 1.4042 - val_acc: 0.5057
# Epoch 4/30
# 4/4 [==============================] - 5s 1s/step - loss: 7.1638e-04 - acc: 1.0000 - val_loss: 1.3933 - val_acc: 0.5035
# Test accuracy with 10000 training samples: 50.35%
# Training with 15000 samples...
# Epoch 1/30
# 4/4 [==============================] - 4s 1s/step - loss: 6.5416e-04 - acc: 1.0000 - val_loss: 1.3730 - val_acc: 0.5085
# Epoch 2/30
# 4/4 [==============================] - 5s 1s/step - loss: 6.6773e-04 - acc: 1.0000 - val_loss: 1.3680 - val_acc: 0.5094
# Epoch 3/30
# 4/4 [==============================] - 5s 1s/step - loss: 5.9135e-04 - acc: 1.0000 - val_loss: 1.3725 - val_acc: 0.5086
# Epoch 4/30
# 4/4 [==============================] - 5s 1s/step - loss: 5.3807e-04 - acc: 1.0000 - val_loss: 1.3721 - val_acc: 0.5094
# Epoch 5/30
# 4/4 [==============================] - 4s 1s/step - loss: 4.9521e-04 - acc: 1.0000 - val_loss: 1.3882 - val_acc: 0.5101
# Test accuracy with 15000 training samples: 51.01%
# Training with 20000 samples...
# Epoch 1/30
# 4/4 [==============================] - 5s 1s/step - loss: 4.5819e-04 - acc: 1.0000 - val_loss: 1.3981 - val_acc: 0.5085
# Epoch 2/30
# 4/4 [==============================] - 4s 1s/step - loss: 4.1449e-04 - acc: 1.0000 - val_loss: 1.4014 - val_acc: 0.5081
# Epoch 3/30
# 4/4 [==============================] - 4s 1s/step - loss: 3.8368e-04 - acc: 1.0000 - val_loss: 1.4220 - val_acc: 0.5078
# Epoch 4/30
# 4/4 [==============================] - 5s 1s/step - loss: 3.5901e-04 - acc: 1.0000 - val_loss: 1.3931 - val_acc: 0.5085
# Epoch 5/30
# 4/4 [==============================] - 4s 1s/step - loss: 3.3409e-04 - acc: 1.0000 - val_loss: 1.4177 - val_acc: 0.5101
# Epoch 6/30
# 4/4 [==============================] - 5s 2s/step - loss: 3.1086e-04 - acc: 1.0000 - val_loss: 1.3965 - val_acc: 0.5089
# Epoch 7/30
# 4/4 [==============================] - 4s 1s/step - loss: 2.9220e-04 - acc: 1.0000 - val_loss: 1.4367 - val_acc: 0.5081
# Test accuracy with 20000 training samples: 50.81%
# |   Training Sample Size |   Test Accuracy |
# |-----------------------:|----------------:|
# |                   1000 |          0.5047 |
# |                   2500 |          0.5038 |
# |                   5000 |          0.5062 |
# |                   7500 |          0.506  |
# |                  10000 |          0.5035 |
# |                  15000 |          0.5101 |
# |                  20000 |          0.5081 |
